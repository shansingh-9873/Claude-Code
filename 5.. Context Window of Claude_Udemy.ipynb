# %% [markdown]
# # 1.. Claude Code Context Window : How AI Agents Remember 🧠

# %%
'''


Hi there 👋 , in this module , we are going to deep dive into

How u can manage Context Window of Claude Code
How does Context Window of Claude Code works 
Some best practises so that u can manage Context Window of Claude Code



━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
🎙️  NARRATION SCRIPT
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

Before we understand the Context Window , we first have to UNDERSTAND what Context is :




Lets connect it with a real-life example !
Imagine YOU are a Software Engineer / App Developer joining a new company .
What is the CONTEXT you need to actually do your job well/ or to your understand project well ?

    a)  Your Codebase 📂
            👉 the functions you have written , the folder structure , the naming conventions ..
            👉 because depending on THIS , you decide what the next line of code should be !

    b)  Your PRD / Spec document 📝
            👉 this is where ALL the requirements are usually written .

    c)  Your Jira / GitHub Issues 🐙
            👉 based on these tools , you get your day-to-day tasks ,
               like a bug or a feature you have to build in your software .

    d)  Slack / Team Messages 💬
            👉 where all your teammates discuss things .

    e)  Previous AI Chats 🤖
            👉 where you have already talked to Codex earlier about this project .

    f)  Git history 🌿
            👉 what changed , when , and why .

👉 ALL of this together is your "context" .


👉 So , what is "Context" ?
    Context is ALL the information needed to understand something correctly ..









👉 So What is a Context Window in Claude Code ?

    The Context Window is the amount of information ( measured in TOKENS )
    that a Anthropic models like OPUS/SONNET/HAIKU can SEE and REMEMBER at one time ,
    while it generates a response for you .

    🧠 Think of it like the model's WORKING MEMORY .


See , LLMs ( like Opus , Sonnet ) can NOT handle infinite context .

    👉 Imagine you have a codebase of 1 MILLION lines .
    👉 You can NOT just dump all 1M lines into the model and ask questions as per that !

Why ?
    👉 Because every model has its OWN limit on how much context it can hold .
    👉 And that limit is measured in TOKENS .
    👉 That token limit is exactly what we call the CONTEXT WINDOW .



━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━




━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
🌍  REAL-WORLD EXAMPLE
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

Let's say you ask Claude Code :

    [show it first] : 
    "Build a end-2-end dashboard for my Amazon Sales Data project"

For Claude Code to do this WELL, it needs context like :

        👉 what columns exist in your dataset
        👉 how Revenue is calculated
        👉 which KPIs you want to show
        👉 your preferred dashboard layout
        👉 which charts are already being used
        👉 your coding style and folder structure


If Claude Code has this context → it writes code that fits your project PERFECTLY .
If it does NOT → it writes generic code that you'll have to fix later .

THIS is why context matters so much ..


━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
🎯  STUDENT TAKEAWAY
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

    👉 Context Window = Codex's WORKING MEMORY .
    👉 Context = ALL the info Claude Code  needs ( codebase , specs , issues , chats , git history ) .
    👉 It is LIMITED , and it is measured in TOKENS .



━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
➡️  TRANSITION TO NEXT TOPIC
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

Now you understand WHAT a Context Window is and WHY it exists .

In the next session , we'll open the hood and understand
        👉 HOW the Context Window of Claude Code  actually WORKS internally —
and why it fills up SO fast 🔥

'''

# %% [markdown]
# # 2.. How the Context Window of Claude Works ⚙️

# %%
'''


Hi there 👋 , in the last session ..
We understood WHAT a Context Window is .

Now let's understand : 👉 HOW does it actually work inside CLAUDE ?



━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
👨‍🏫  INSTRUCTOR EXPLANATION
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

📌 IMPORTANT POINTERS about CLAUDE models :

    👉 In Claude Code today , a Sonnet model has a context window of around 200K tokens
                         and Opus Models can run with context window as large as 1M tokens ..
                         
        [Open VS CODE] : run /context with Sonnet model selected
        then switch model using : /switch to Opus
        run /context again : now u will see Context window of 1 tokens 
                         

    👉 Every time , u start a new conversation with Claude Code if u are using Opus , 
        fresh context window will be around 1M tokens
        

    👉 Models have a limit of 1M tokens & they will be consumed by your questions + Claude Code REplies
        Your query ->> I/P tokens
        Codex replies ->> Output Tokens


💡 One more practical note :
    Claude Code replies ( output tokens ) often cost MORE than your questions ( input tokens ) ,
    because the reply includes generated code , explanations , and the results of tools it runs .





Now here comes the MOST IMPORTANT concept of this whole section 🔥 :

    👉 LLMs are STATELESS — they do NOT have memory of their own !

        What does "stateless" mean ?
            👉 It means the model does NOT actually remember your previous messages on its own .

        So then .. how does Claude "remember" your conversation ? 🤔

        👉 Here is the trick :
           Every time you send a new message , Claude Code SECRETLY re-sends the ENTIRE conversation so far
           ( all your previous questions + all the model's previous replies ) back to the model
           as INPUT tokens .

        👉 That is the ONLY way the model can "remember" — by re-reading everything each turn .

⭐ THIS is the reason your context window fills up SO fast !


Let's have a rough estimate of count tokens turn-by-turn .
Imagine each of your messages and each Claude reply costs about 100 tokens :

    Turn 1 :   [ you ] [ Claude Code ]                                             →  ~200 tokens
    Turn 2 :   [ you ] [ Claude Code ] [ you ] [ Claude Code ]                     →  ~400 tokens
    Turn 3 :   [ you ] [ Claude Code ] [ you ] [ Claude Code ] [ you ]Claude Code] →  ~600 tokens
       ..
    Turn 10 :  ( all previous conversation re-sent ) ..           →  ~2000 tokens

👉 See the pattern ?
   Every new turn drags ALL the previous turns along with it .

    🔑 Conclusion :
        Bigger the size of your session / conversation ,
        HIGHER the chance your context window gets EXHAUSTED .









━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
🌍  REAL-WORLD EXAMPLE
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

Let's say you start a Claude Code session to collect amazon users from 5 Sources & dataset sizes are quite Big Upto TBs  !
[Show VSCODE]


    1 source ->> CSV
    2 source ->> Database
    3 Source ->> Big Data Sources
    4 source ->> WEB Scraping
    5 source ->> JSON
    
    So u can create multiple sessions ( 1 session for each source) else your limit will be exhausted !
    



━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
🎯  STUDENT TAKEAWAY
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

    👉 Context window is a TOKEN limit ( ~1M for current Opus models  ) .
    👉 LLMs are STATELESS — Claude Code re-sends the WHOLE conversation each turn so the model can "remember" .
    👉 That is exactly WHY long sessions fill the window fast .
    👉 Good practice ( we'll prove this later ) :  ONE focused session / thread per feature .


'''

# %% [markdown]
# # 3.. Components of the Claude Code Context Window ( in detail ) 🧩

# %%
'''


Hi there 👋 , in the last session ..
We understood HOW the context window works , and why it fills fast .

Now let's open it up and see : 👉 WHAT exactly is INSIDE the Codex context window ?


━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
🎙️  NARRATION SCRIPT
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

Here is a very important idea first :

    👉 A Sonnet Model have a 200k context window ,
       but the window you can ACTUALLY use is a little smaller .

It's just like buying a laptop with 8GB of RAM 💻 ..
        👉 the OS already eats some of it , so the USABLE RAM is less than 6 or 7GB .

Same with Claude Code : some of the window is ALREADY occupied the moment your session starts ,
and some is RESERVED in advance .. 


━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
👨‍🏫  INSTRUCTOR EXPLANATION  —  the layout of the window
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

🧩 Claude Context Window ( who lives where ) :

    ┌───────────┬──────────┬──────────┬───────────────────┬──────────┬───────────┬───────┐
    │  System   │  Tool    │ CLAUDE   │   Conversation    │  Tool    │  Auto-    │ Free  │
    │  Prompt   │  Schemas │  .md     │     History       │ Results  │  Compact  │       │
    └───────────┴──────────┴──────────┴───────────────────┴──────────┴───────────┴───────┘
       (system instructions)   (project memory)              (Skills + MCP)   (reserved)


Let's go through each tenant one by one 👇


1) 🧠  System Prompt
        👉 When you start a session , CLAUDE loads a set of built-in instructions ( the system prompt ) .
        👉 These instructions are designed by Anthropic & This takes up some tokens before you even type anything ..
        
        As of June 12, 2026 , There are Total 515 Total System Prompt Files : 
        which Anthropic intentionally compiles it into npm package bcz of : 
            ✅ Protection & 
            ✅ Performance
            
        & since they are compiled into NPM package ,  they're not stored as visible files on your Windows machine. !
        
        
        
        
        
        As of June 12, 2026 , There are Total 515 Total System Prompt Files : 
        👉 GitHub Repo: https://github.com/Piebald-AI/claude-code-system-prompts
        
            ├── Main System Prompt (~110 conditional instructions)
            ├── 27 Builtin Tool Descriptions
            │   ├── Bash tool
            │   ├── File editor
            │   ├── Web search
            │   ├── Code execution
            │   └── 23 other tools
            ├── Sub-Agents (3 prompts)
            │   ├── Plan mode (715 tks)
            │   ├── Explore mode (575 tks)
            │   └── Task mode
            ├── Utility Prompts (8-10 files)
            │   ├── CLAUDE.md creation (384 tks)
            │   ├── Status line setup (2433 tks)
            │   ├── /code-review (multiple effort modes)
            │   ├── /batch command
            │   ├── /compact
            │   ├── Security review
            │   └── Agent creation
            ├── System Reminders (~40 files)
            └── Tool Parameters & Helper Functions
        
        
        Q.. What does System Prompt contains ? 
        Ans.. The system prompt includes:

            Identity & security guidelines
            Task execution rules (don't over-engineer, read before modifying)
            27+ built-in tool definitions (bash, file editor, web search, etc.)
            Sub-agent prompts (Plan mode, Explore mode, Task mode)
            Code review, batch processing, and utility prompts
        
        
        Q.. How to Access the System Prompts?
        Ans. Since the system prompts are compiled in the npm package, they're not stored as visible files on your Windows machine.


        Q.. Why Are They Compiled & Protected?
        ⚠️ Anthropic intentionally compiles system prompts into the npm package because:

        ✅ Protection — Prevents users from accidentally (or maliciously) modifying core instructions before Claude Code runs
        ✅ Performance — Compiled code loads faster than reading separate files on every session start
        ✅ Integrity — Ensures consistent, predictable behavior across all users worldwide

        BUT — You CAN read them from the GitHub reference repository:
        👉 GitHub Repo: https://github.com/Piebald-AI/claude-code-system-prompts


        

2) 🛠️  Tool Schemas
        👉 Remember :  CLAUDE CODE = LLM + TOOLS .
        ie all the built-in Tools which Claude uses to get the work done !
           eg write , bash , grep, websearch  , they also consume tokens !
        👉 Every tool ( read , edit  , Bash Tool , websearch , etc. ) has a SCHEMA :
               - the definition of the tool
               - what the tool can do
               - what INPUTS the tool needs
               - what OUTPUTS the tool returns
        👉 All these schemas sit inside the context window and consume tokens .

3) 📄  CLAUDE.md   ←  ( this is Claude Code project-memory file ! )
        👉 CLAUDE.md is loaded at the START of your session .
        👉 It is like an "overview" file for your project .
        👉 Inside it you keep : coding standards , function naming , tech-stack , what to do , what NOT to do .


4) 💬  Conversation History
        👉 As we learned , this is your messages + Claude Code replies , re-sent every turn .
        👉 This is usually the FASTEST-growing part
        
        
5) 📤  Tool Results
        👉 Every tool CLAUDE CODE runs , it produces some output ( file contents , command logs , test output ) .
        👉 This output is often VERBOSE , and it ALSO needs tokens to live in the window .

6) ⚡  Skills + MCP tools
        👉 Skills ( your reusable task playbooks ) consumes tokens !
            Similarly when u want to connect external Tools into your workflow , thats where MCP comes !
            and MCP tools also consumes tokens !
          



7) 🗜️  Auto-Compaction Reserve
        👉 Codex keeps a chunk of the window RESERVED for compaction ( we'll cover this next session ) .

8) 🟢  Free
        👉 Whatever is left over — this is the room you ACTUALLY have to work in .





In the next session , we'll understand : 👉 What is Auto-Compaction , and how Codex uses it
to keep your long sessions alive 🗜️

'''

# %% [markdown]
# # 4.. Auto-Compaction in Claude Code

# %%
'''


Hi there 👋 , in the last session ..
We saw every component inside the context window !

Now let's understand : 👉 What is Auto-Compaction , and why does Claude Code do it ?


━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
🎙️  NARRATION SCRIPT
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

    Around 60-70k Tokens are reserved for Auto compaction !
    Its' like 

    Context window usage :
    [████████████████████░░░░]   ← imagine you're at 80–90% of Context Window usage , say ~350K tokens used


So what does Claude Code do to save you ?
        👉 It COMPACTS the context — it summarises the conversation so far into a much
           shorter form & store it into a Auto-compaction buffer !

When Claude Code does this AUTOMATICALLY , we call it AUTO-COMPACTION .




[VS CODE]  show : 
    Imagine I am using Claude Code 
    my window is ~80–90% full ? 
    run : [/context in VS CODE Claude Code Chat panel]

    How do I handle it ?"

    There are 2 ways to do AUTO-COMPACTION : 


    a)  Let Claude Code handle it AUTOMATICALLY 
            👉 Claude Code summarises conversation & store it into Auto Compaction Buffer & makes your token usage free !
            👉 But remember : it's not loss-less( it means u will loose some essence of info while summarising) 
                    , and Claude Code may trigger LATE .
            
        But when Auto-compaction buffer fills , Claude Code will not allow u to chat, degrades response quality 
        So close that session & create a new one !
        
        

    b)  Handle it MANUALLY with the  /compact  command  ⭐ ( the better habit )
            👉 You decide WHEN to compact , before quality of Claude Code drops .
            👉 run /compact command !
                [ Show /compact via VSCODE :]
            
            
        

'''

# %% [markdown]
# #### Why the Context Window Matters 💸

# %%
'''


Hi there 👋 , in the last session ..
We learned how Claude Code rescues long sessions with auto-compaction .

Now let's understand : 👉 WHY should you even care about the context window ?
There are TWO big reasons : COST and QUALITY .


━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
🎙️  NARRATION SCRIPT
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

Reason 1 — 💰  COST

    👉 Remember : every turn re-sends the whole conversation as input tokens .
    👉 More tokens in the window  →  more tokens processed every turn  →  HIGHER cost .

    So a bloated context window is literally burning your usage / your money .


Reason 2 — 📉  QUALITY DEGRADATION

    👉 As your context window FILLS UP , the OUTPUT QUALITY of Codex starts to DROP .

━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
👨‍🏫  INSTRUCTOR EXPLANATION
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

Let me show you the danger zone visually :

    Context window usage :
    [████████████████████░░░░]   ← imagine you're at 80–90% , say ~120K tokens used

    Now , at this point , if you give Codex a brand-NEW task ..
        👉 the output QUALITY will likely DECREASE .
        👉 responses also get SLOWER , because the model is chewing through more tokens per turn .
        👉 So compress the conversation !




'''

# %% [markdown]
# # 5.. Good Practices to Handle the Context Window 🏆

# %%
'''


━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
👨‍🏫  INSTRUCTOR EXPLANATION  —  THE GOOD-PRACTICES CHECKLIST
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

Imagine you're an AI Engineer / Data Analyst working on an Amazon Product Analytics platform.

Your task is to collect and analyze data from multiple sources:

📄 CSV files
🗄️ SQL Databases
☁️ Big Data Sources (Spark / Hadoop)
📦 JSON APIs
🌐 Web Scraping




to collect such data : 

    Product Name
    Price
    Discount %
    Ratings
    Reviews
    User Information
    Product Category
    Seller Information
    Inventory Status




✅ 1) ONE thread / session per feature

    ✅ GOOD: Create separate sessions: 
    Session 1 → CSV Data Ingestion 
    Session 2 → Database Pipeline 
    Session 3 → Web Scraping Pipeline 
    Session 4 → Review Sentiment Analysis 
    Session 5 → Dashboard Development 
    
    👉 Every new session starts with a fresh context window. 
    👉 Faster responses. 
    👉 Lower token usage. 
    👉 Better code quality.
    
    
    
    
✅ 2) Check /status periodically and /compact proactively

    Your window is filling quickly. 
    Run: /context to check context usage. 
    
    Before reaching the danger zone: /compact
    
    
    
✅ 3) Write focused, polished, SPECIFIC prompts

    ❌ BAD:

            Analyze my Amazon data.
            
            
            
    ✅ GOOD: Extract average product ratings, total reviews, and price distribution from amazon_reviews.csv.
    
    👉 Precise prompts = fewer tool calls. 
    👉 Fewer tool calls = lower token cost. 
    👉 Lower token cost = longer sessions.






✅ 4) Use SUBAGENTS for parallel / heavy work 🤖

    Imagine your Amazon project contains:

            20 million reviews
            5 data sources
            multiple ETL pipelines

    Instead of doing everything in one window:

    Create specialized subagents.

    🤖 Data Extraction Agent

            Collects:
                - CSV data
                - Database records
                - JSON feeds

    🤖 Web Scraping Agent

            Extracts:
                - product prices
                - ratings
                - reviews

    🤖 Sentiment Analysis Agent

            Processes:
                - customer reviews
                - review sentiment
                - complaint detection



Every subagent gets its OWN context window. 

So: Main Agent Window 
            ↓ 
    delegates work 
            ↓ 
    Subagent Window #1 
    Subagent Window #2 
    Subagent Window #3




'''
