# %% [markdown]
# # 📜 SECTION 6 : CLAUDE..md — YOUR PROJECT'S BRAIN
#
# **Goal of this section :**
# HI there,  in this section we will understand what is the Brain of the Agent which is again a file
# known as CLAUDE..md !
#
# So By the end of this section you will :
#
# **Lectures :**
# 1. What CLAUDE..md Is and Why It Matters
# 2. 3 ways to create CLAUDE.md !
# 3. Writing Your First CLAUDE..md from scratch
# 4. Testing Your CLAUDE..md
#
#
# **Project we will use throughout :**  Amazon_data_analysis  ( Python )

# %% [markdown]
# # Lecture 1 : What CLAUDE.md Is and Why It Matters

# %%
'''

========================================
PART 1 — Why CLAUDE.md Matters
========================================



So before understanding What is CLAUDE.md , lets first understand why there is a need of CLAUDE.md !


let say : You are a Data Engineer at Amazon & your Job is to make Insights from Amazon Data !

    So You spent 2 hours with CLAUDE & built amazing things !


    You have : 

    Collected Amazon sales data from various sources 
    Then [show dashboard] : 
        Performed Data Analysis 
        Built KPIs (Total Revenue, Total Orders , Top-Selling Products)
        Built dashboards so that u can showcase it to Business Team/Managers 
    
    
    
    
    
Everything is working perfectly.
You’re confident.
You’re proud..





Now next day… Your Manager says :
👉 "Can you improve this Amazon Sales Dashboard and add more business insights?"
    eg like : Impact of Festivals on Sales ?
              Analysing Peak hour sales !



Then You open a new AI session in Claude Code !
And you say:
    👉 “Help me improve my Amazon analysis dashboard as I want to add these following Insights”

And suddenly…
Then Claude asks:

    👉 "What does your dataset look like?"
    👉 "What columns are available?"
    👉 "How are you calculating Total Revenue?"
    👉 "Which KPIs have already been implemented?"
    👉 "How is the dashboard currently structured?"


And you’re like…
😩 “I already explained all of this yesterday!”
    So its Frustrating… right?

[Pause]



👉 Bcz LLMs like Claude don’t have memory across sessions..
    LLMs are memory-less / stateless 
            OR
    Claude don’t remember anything across sessions.

They only remember what’s inside the current conversation/session..
And this creates a HUGE problem…






So now the question is…

👉 How do we make Claude REMEMBER our project?"
    One way is : Explain things from scratch into every new session ( thats practically impossibe 
                    in bigger projects & this is so error-prone)
                    
    Second way is : You could give Claude Code one file… & that file contains all your
                    Project info 
                    And whenevr u start a new session  , Claude will read that file & understands your entire project instantly 
                    & that file is known as CLAUDE.md !
                    





========================================
PART 2 — A Simple One-Line Definition
========================================


CLAUDE.md is :

    👉 A plain text/markdown file in your project folder which contains your project's rules, conventions, and warnings.
                                            OR
        CLAUDE.md is like a context & context is everything when u are working LLMs like CLAUDE



In simple words —

    👉 README.md  is designed for humans which tells what your project does..
    👉 CLAUDE.md  is designed for CLAUDE which tells to your Claude Agent what your project is all about 


    👉 README.md  =  for humans  ( what your project does )
    👉 CLAUDE.md  =  for CLAUDE   ( how YOUR project should be worked on )
                    ie it is like a : rule-book + Summary of your Project for CLAUDE which tells CLAUDE :
                                                    -> What your Project is :
                                                    -> How your Code is structured :
                                                    -> What Tools & libraries u are going to using 




========================================
PART 3 — Where Does this "CLAUDE.md" Live ?
========================================


Super simple.

    👉 It lives in the ROOT of your project folder or in .claude folder !
    👉 The filename is exactly :   CLAUDE.md



Example : How folder structure for our project looks like :


    📂 Amazon/
        ├── 📜 CLAUDE.md            ← this is the magic file
        ├── 📜 README.md             ← for humans
        ├
        ├── 📂 data/
        │     └── amazon_sales_customer.sqlite          ( product_name, quantity, Price, region )
        └── 


                                    OR
                    

    📂 Amazon/
        ├── 📜 README.md             ← for humans
        ├
        ├── 📂 .claude/
        │     └── CLAUDE.md          
        ├── 📂 data/
        │     └── amazon_sales_customer.sqlite           ( product_name, quantity, Price, region )








Claude sees CLAUDE.md in the root → reads it → applies your rules.
Done.

Now in the next session , we will write First CLAUDE.md file !
See you in Lecture 2 !"


'''

# %% [markdown]
# # Lecture 2 : 3 ways to create CLAUDE.md !

# %%
'''


1 ) U can ask CLAUDE AI/Claude CODE to generate CLAUDE.md !
2 ) using slash command (/init )
3 ) Write CLAUDE.md from Scratch !





1 ) U can ask CLAUDE AI to generate Claude.md !
    Open Claude Code/ AI/ Claude Desktop !
    say : Generate nice formatted CLAUDE.md file for for this Python project under 200 lines !
          Then u can edit this file "CLAUDE.md" as per need !



2 ) "Now lets design CLAUDE.md using /init command !
    [VSCODE]

   run /init command !
   Once u run this command , CLAUDE internally calls an Agent which will scan your entire codebase & create CLAUDE.md file !
   
   /init is much better than Manual approach bcz :
   At Day 1 , U may not have entire knwoledge about Project , thats where /init will be handy !
   
   Generally , it is observed that : CLAUDE.md will be 30% useful if it has been generated from /init
   remaining , 70% will be designed by you !
       like : 
       u can manually explain workflows
       U can tell constraints
       U can tell CLAUDE what to avoid
       U can tell CLAUDE Naming conventions
       U can tell CLAUDE how to deploy this project
       
       
       Best-practise : /init + Manual approach 

   
   
3 ) Designing it from scratch    

   
   

'''

# %% [markdown]
# # 3.. Writing Claude.md  !

# %%
'''

Hi  , so now lets talk about how to create Optimal CLAUDE.md file for our Agent !


   
Open your project root.
Open this -  Claude.md

Now We are going to teach Claude EVERYTHING about this project
in one small file "CLAUDE.md"




But first Lets talk about 5 imp Sections that Matters for this CLAUDE.md
========================================
PART 1 — The 5 Sections That Matter
========================================

So its a good practise to include these 5 sections !

    1️⃣  Project Overview         →  what is this project ?
    2️⃣  Tech Stack                →  what tools and libraries we use
    3️⃣  Folder Structure          →  where things live
    4️⃣  Code Style                →  naming, formatting, conventions
    5️⃣  Don't Touch Rules         →  files Claude must NEVER edit

so these are 5 imp ones !

Optionally you can add — testing rules, commit message style, etc.
But for beginners, these 5 are more than enough.






========================================
PART 2 — Let's Build Each Section, Step by Step
========================================

[VS CODE]
─────────────────────────────────────────
SECTION 1 — Project Structure
─────────────────────────────────────────

Goal : Tell Claude in 2-3 lines how your project files and folders are organized. !

# Claude Project Standards & Instructions

## Overview
This project follows best practices for Python development, focusing on clarity, maintainability, and reliability. All contributors are expected to adhere to the standards outlined below.







## Project Structure
- Organize code into logical modules and packages.
- Use descriptive folder and file names.
- Separate notebooks, scripts, and utility files.
- Keep documentation and media assets in dedicated folders.










─────────────────────────────────────────
SECTION 2 — Coding Standards
─────────────────────────────────────────

─────────────────────────────────────────
          PEP 8 Compliance
─────────────────────────────────────────
PEP 8 is Python's official style guide. 
It provides rules for formatting code, naming variables, spacing and overall code appearance.



- **PEP 8 Compliance:** Follow [PEP 8](https://peps.python.org/pep-0008/) for code style.


─────────────────────────────────────────
         Type Annotations
─────────────────────────────────────────
They improve code clarity and help catch errors early.

- **Type Annotations:** Use type hints for functions and classes.





─────────────────────────────────────────
        — Docstrings
─────────────────────────────────────────
Docstrings are descriptions about what Code does & 
    it is written inside functions, classes, and modules. 



- **Docstrings:** Document all public functions, classes, and modules using [PEP 257](https://peps.python.org/pep-0257/).
- **Naming:** Use clear, descriptive names for variables, functions, and classes.
- **Functions Naming:** Use `snake_case` for functions and methods.
- **Error Handling:** Use exceptions thoughtfully; catch only what you can handle.
- **Immutability:** Prefer immutable data structures when possible.








─────────────────────────────────────────
requirements.txt
─────────────────────────────────────────
This file lists all Python packages required by the project.

- Use `requirements.txt` to specify dependencies.




─────────────────────────────────────────
        Version Pinning
─────────────────────────────────────────

Specifying exact package versions prevents compatibility issues. 

- Pin versions for critical packages.




─────────────────────────────────────────
Documentation
─────────────────────────────────────────

Documentation explains how the project works and how to use it.


- Maintain clear and concise README files.
- Use Markdown for all documentation.
- Document setup, usage, and contribution guidelines.

---

## Notebooks
- Keep notebooks clean and well-commented.
- Use Markdown cells for explanations.
- Avoid storing large outputs or data in notebooks.

---

## Contribution Guidelines
- Follow the standards above.
- Review code before submitting pull requests.
- Be respectful and collaborative.

---

## Useful Resources
- [PEP 8 – Style Guide for Python Code](https://peps.python.org/pep-0008/)
- [PEP 257 – Docstring Conventions](https://peps.python.org/pep-0257/)
- [pytest Documentation](https://docs.pytest.org/en/stable/)
- [Python Official Documentation](https://docs.python.org/3/)










So make sure , you provide right context or to the point information in Claude.md !
Do not put over-information !
Do not complicate !
Create CLAUDE.md under 200 Lines 






Now in the next lecture — let's actually TEST our Claude.md.

We will ask Claude to read this database 
and watch — does it follow our rules ? Or does it break them ?

See you in Lecture 3 !"








'''

# %% [markdown]
# # Lecture 4 : Testing Your CLAUDE.md

# %%
'''

"People always make ONE big mistake with CLAUDE.md

They write the file —
and then ASSUME CLAUDE is following it.

Don't assume. 
ALways TEST.


========================================
PART 1 — Testing CLAUDE.md
========================================


Testing CLAUDE.md is super simple. Just 3 steps :

    1️⃣  Give Claude Code a small NEW task in the project.
    2️⃣  Watch what it generates.
    3️⃣  Score it against your CLAUDE.md rules.


If CLAUDE follows 90%+ rules — your CLAUDE.md is solid ✅
If it breaks rules — your CLAUDE.md needs improvement 🔧



========================================
PART 2 — Our Test Task
========================================
[VSCODE]

Open your CLAUDE chat Panel in the VS CODE !
Make sure your CLAUDE.md is saved in Project Root or .claude folder !


SO if you Want to confirm CLAUDE is READING your CLAUDE.md or not ?
Use this simple trick.

Just ask CLAUDE —

    👉 'Before doing any task, list the top 5 rules
        from my CLAUDE.md file in your own words.'





Now lets test results : 
    Now type this exact prompt :


    👉 Read this @data/amazon_sales_customer.sqlite  using pandas function!
                                OR
        create a dataframe generation code using pandas
    
    
    
    
    



========================================
PART 3 — The Scoring Checklist
========================================


When CLAUDE finishes its work , do a review !

Here is your checklist for our project —

PEP 8 Compliance	                    ✅	Looks compliant.
Type Annotations	                    ✅	load_data() is typed.
Module Docstring	                    ✅	Module-level docstring exists.
Function Docstring	                    ✅	Function is documented.
Clear Naming	                        ✅	load_data, db_path, df are understandable.
snake_case Functions	                ✅	Correct.


 But when u edit in CLAUDE.md & say it to camel_case  , 
 *Function Naming* : Use camel_case for function & methods !
 
 then CLAUDE wil generate by following camel_case ( )
         The first word starts with a lowercase letter
         Every new word starts with a capital letter
         No spaces or underscores are used




Count your score : 6 / 6  →  CLAUDE.md is excellent  🏆





========================================
PART 4 — When CLAUDE Breaks a Rule — How to Iterate
========================================


Don't panic when CLAUDE breaks a rule.
It happens. It is part of the process.

Here is the iteration loop —


🔁  THE CLAUDE.md ITERATION LOOP :

        1️⃣  Spot the rule that was broken.
        2️⃣  Ask WHY — was the rule vague or missing ?
        3️⃣  Write more SPECIFIC rule
        4️⃣  Save CLAUDE.md.
        5️⃣  Run the SAME prompt again.
        6️⃣  Recheck the output.

Repeat until the rule is followed 95% of the time.




========================================


!"

'''
