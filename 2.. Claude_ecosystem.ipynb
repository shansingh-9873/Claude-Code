# %% [markdown]
# # 1.. Claude AI vs Claude Code vs Claude Cowork

# %%
'''


So yeah , Hi :


[show img]
"Let me tell you something honestly…
Bcz thats where where most beginners get stuck..


[show anthropic page]
They hear:

    Claude AI…
    Claude Code…
    Claude Cowork…

And they think…

👉 hye , ‘What is going on?’
    In layman terms , these 3 are the different products released by Claude or Anthropic Company !
    
So let’s simplify this for you !

So Anthropic have 3 products !
They have:
    🧠 Claude Chat (Claude AI) → Brain where u are directly interact with Claude LLM
    👨‍💻 Claude Code → Engineer ( where u have Claude LLM + it has access to tools so that it can write code,access your project)
    ⚙️ Claude Cowork → Operator

Now let’s break this down.

🧠 Claude AI (Claude Chat)
    👉 Its Just like ChatGPT / Gemini 


    where You ask questions…
    It gives answers.


    [show UI]
    Like when you go to claude , this is Claude Chat !
    where u can ask your query like : hey , What is What is Agentic AI ?
    
    

But…

It only gives text  , code  , PPTs or Image output..
It doesn’t build real things.




👨‍💻 Thats where Claude Code comes 


This is not just chatbot..
[show VS Code]
This can be used inside your Project & it will help you to build things !
You can see separate terminal for Claude in your IDE !
That is Claude code !


It can:

    ✔ Write code in your files 
    ✔ Read files
    ✔ Run commands
    ✔ Build applications

So instead of answering…
    👉 It executes



⚙️ Coming to Claude Cowork

    This is like an operator.

    It handles:

        ✔ Workflows
        ✔ File access
        ✔ Browser usage
        ✔ Tool connections

    Think of it like:
    👉 Someone who runs operations



So If I simplify everything in one line:

🧠 Claude AI → The brain that thinks
👨‍💻 Claude Code → The engineer that builds
⚙️ Claude Cowork → The system that runs operations



That’s it.
Now here’s the important part…

👉 In this course, we focus on Claude Code
    Because that’s where real power is.



'''

# %% [markdown]
# # 2.. Models in Claude : Opus vs Sonnet vs Haiku !

# %%
'''


Hi there , in the last session we have understood Claude ecosystem !
Now lets understand various models of Claude !


Anthropic who owned Claude have various models like 

Opus
Sonnet
Haiku


Even if u go to Claude 
[google as : claude models] , u can see they have these 3 models 
    which Claude Code is using under the Hood !






If u want to have 1 line diff between when to use which Model :

Use opus for Planning  phase , complex Workflows
    Imagine YOur company want to built a scalable product like Google which can Handle Millions of searches per second
    Thats where u can use OPus !

Use Sonnet for Implementation phase , day-2-day coding 
Use Haiku for day-2-day conversation & simple work !




If u want simple & quick table comaprison between 3 Claude Models , here is that :

Use opus for Planning phase , complex Workflows/programming tasks 
    Imagine YOur company want to built a scalable product like Google which can Handle Millions of searches per second
    Opus models generally consumes 2X Tokens than Sonnet,  so never use OPUS for simple tasks !

Use Sonnet for Implementation phase , day-2-day coding tasks
    As It has balance of speed + Token cost 
    
Use Haiku for day-2-day conversation & simple work !
    It is cheapest model & used for simple tasks !



'''

# %% [markdown]
# # 3.. What is Agentic Coding (VERY simple) ?

# %%
'''

Hi there , 
"till now you understand various Claude models which Claude Code uses under the Hood…
Let’s talk about the most exciting concept — Agentic Coding."


Let’s break it"Agentic Coding" down :

    👉 Agent = AI that can perform tasks
    👉 Agentic = Multiple agents like agent1 , agent2 , agent3 & they are  working together

That’s it..

    Coding : set of instructions/Code which u give to system or to Agent to perform certain tasks !



Now imagine this…
👉 You want to build a website like Udemy.

    [ show Udemy without sign-In]
    A full platform where:

    Users can sign up
    Instructors can upload courses
    Students can watch videos
    
    normally… , This is a HUGE complex project !

    You would need:

        Frontend developer
        Backend developer
        Database engineer
        DevOps

        And it could take Months to build a such a Scalable Product like Udemy !

    But now…

    Let’s do the same thing using Agentic Coding.
    Instead of doing everything yourself…

    👉 You create a TEAM of AI agents.
            OR
    You assign tasks by creating multiple agents : 

    👨‍💻 Agent 1 → Build UI
    👨‍💻 Agent 2 → Handle backend
    👨‍💻 Agent 3 → Database Agent




SO Claude can create :
👉 Sub-agents
👉 which work in parallel & build all these things..


& This is amazing !

Because:

👉 Your Work becomes faster
👉 Tasks don’t mix up
👉 System becomes scalable


Now think like a manager…
You don’t have to code everything…

👉 You just assign work & Agents will do it & u have to validate the work !


That is : 👉 Agentic Coding


'''

# %% [markdown]
# # 4.. Why only Claude Code ?

# %%
'''

HELLO all , in this session , we will be understanding Why only Claude Code ?
    Why not other Tools in Agentic AI like :
        Codex By OpenAI
        Cursor
        Windsurf
        Replit
        Loveable
        
        
        
        1st reason is : Highly adopted Industry Tool & nowdays Recruiters are demanding whether u can work with Claude Code or not !

        2nd reson : It is the most powerful tool for coding nowadays bcz uing Claude Code , u can actually 
                    Scalable products !
                    U can build websites
                    U can build dashboards
                    U can build Data domain Projects ( ML , DL , NLP )
                    
                    
        3rd reason : Best raw coding Intelligence 
                    Its premmum OPUS Model is used for coding tasks
                    & using this model , you can add complex features in complex applications very very easily 
                    
                    
        4th Reason : Agentic Capablities
                    Imagine you are building a S/W project !
                    U can actually build agents parallelly
                    like :
                    u can build Testing Agent , which will Test your code
                    u can build agent for Code Review, whch can reviw your code
                    



'''
